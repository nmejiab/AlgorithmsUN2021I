# %% [markdown]
# ##**Lab 9 - Bubble Sort Optimized Distribution With Repetition**

# %% [markdown]
# Función bubble sort optimizada

# %%
def BSOpt(arr): 
  # recorre los elementos del arrreglo
  for i in range(len(arr)):
    perm = False
    pasos = 0
    # compara elementos del arreglo
    for j in range(0, len(arr) - i - 1):
      pasos +=1
      if arr[j] > arr[j + 1]:
        #intercambia elementos si no están en orden
        temp = arr[j]
        arr[j] = arr[j+1]
        arr[j+1] = temp
        pasos +=1
        perm = True
    if not perm:
      break
  return pasos

# %% [markdown]
# Permutaciones con repeticiones

# %%
from itertools import product

n=3 
perm = product(range(1,n+1), repeat = n)

c=0
for i in perm:
    print(i)
    c+=1

print(c)
# Out:
# (1, 1, 1)
# (1, 1, 2)
# (1, 1, 3)
# (1, 2, 1)
# (1, 2, 2)
# (1, 2, 3)
# (1, 3, 1)
# (1, 3, 2)
# (1, 3, 3)
# (2, 1, 1)
# (2, 1, 2)
# (2, 1, 3)
# (2, 2, 1)
# (2, 2, 2)
# (2, 2, 3)
# (2, 3, 1)
# (2, 3, 2)
# (2, 3, 3)
# (3, 1, 1)
# (3, 1, 2)
# (3, 1, 3)
# (3, 2, 1)
# (3, 2, 2)
# (3, 2, 3)
# (3, 3, 1)
# (3, 3, 2)
# (3, 3, 3)
# 27

# %% [markdown]
# Función de histogramas y análisis

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 

n = 3
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in list(perm):
    i = list(i)
    times.append(BSOpt(i))

b = np.array(range(min(times)-1,max(times)+2) ) +0.5
plt.hist(times,bins=b)
plt.title("Bubble Sort Optimized repetitions")
plt.xlabel("Steps = comparisons + swaps ")
plt.ylabel("Frequency")
plt.show()
    
print("n",n)  
print("number of permutations ,n**n = ",n**n)
print("exp min =",min(times))
print("min formula (n-1)*n/2 =",(n-1)*n/2)
print("exp max =",max(times))
print("max formula (n-1)*n =",(n-1)*n)
print("exp mean =",np.mean(times))
print("mean formula (3/4)*(n**2)-n+(1/4) =",(3/4)*(n**2)-n+(1/4))
print("stdev",np.std(times))
# Out:
# n 3
# number of permutations ,n**n =  27
# exp min = 0
# min formula (n-1)*n/2 = 3.0
# exp max = 2
# max formula (n-1)*n = 6
# exp mean = 1.1851851851851851
# mean formula (3/4)*(n**2)-n+(1/4) = 4.0
# stdev 0.7219847662821455

# %%
n = 4
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in list(perm):
    i = list(i)
    times.append(BSOpt(i))

b = np.array(range(min(times)-1,max(times)+2) ) +0.5
plt.hist(times,bins=b)
plt.title("Bubble Sort Optimized repetitions")
plt.xlabel("Steps = comparisons + swaps ")
plt.ylabel("Frequency")
plt.show()
    
print("n",n)  
print("number of permutations ,n**n = ",n**n)
print("exp min =",min(times))
print("min formula (n-1)*n/2 =",(n-1)*n/2)
print("exp max =",max(times))
print("max formula (n-1)*n =",(n-1)*n)
print("exp mean =",np.mean(times))
print("mean formula (3/4)*(n**2)-n+(1/4) =",(3/4)*(n**2)-n+(1/4))
print("stdev",np.std(times))
# Out:
# n 4
# number of permutations ,n**n =  256
# exp min = 0
# min formula (n-1)*n/2 = 6.0
# exp max = 3
# max formula (n-1)*n = 12
# exp mean = 1.50390625
# mean formula (3/4)*(n**2)-n+(1/4) = 8.25
# stdev 0.89703525081846

# %%
n = 5
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in list(perm):
    i = list(i)
    times.append(BSOpt(i))

b = np.array(range(min(times)-1,max(times)+2) ) +0.5
plt.hist(times,bins=b)
plt.title("Bubble Sort Optimized repetitions")
plt.xlabel("Steps = comparisons + swaps ")
plt.ylabel("Frequency")
plt.show()
    
print("n",n)  
print("number of permutations ,n**n = ",n**n)
print("exp min =",min(times))
print("min formula (n-1)*n/2 =",(n-1)*n/2)
print("exp max =",max(times))
print("max formula (n-1)*n =",(n-1)*n)
print("exp mean =",np.mean(times))
print("mean formula (3/4)*(n**2)-n+(1/4) =",(3/4)*(n**2)-n+(1/4))
print("stdev",np.std(times))
# Out:
# n 5
# number of permutations ,n**n =  3125
# exp min = 0
# min formula (n-1)*n/2 = 10.0
# exp max = 4
# max formula (n-1)*n = 20
# exp mean = 1.78144
# mean formula (3/4)*(n**2)-n+(1/4) = 14.0
# stdev 1.031926124487601

# %%
n = 6
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in list(perm):
    i = list(i)
    times.append(BSOpt(i))

b = np.array(range(min(times)-1,max(times)+2) ) +0.5
plt.hist(times,bins=b)
plt.title("Bubble Sort Optimized repetitions")
plt.xlabel("Steps = comparisons + swaps ")
plt.ylabel("Frequency")
plt.show()
    
print("n",n)  
print("number of permutations ,n**n = ",n**n)
print("exp min =",min(times))
print("min formula (n-1)*n/2 =",(n-1)*n/2)
print("exp max =",max(times))
print("max formula (n-1)*n =",(n-1)*n)
print("exp mean =",np.mean(times))
print("mean formula (3/4)*(n**2)-n+(1/4) =",(3/4)*(n**2)-n+(1/4))
print("stdev",np.std(times))
# Out:
# n 6
# number of permutations ,n**n =  46656
# exp min = 0
# min formula (n-1)*n/2 = 15.0
# exp max = 5
# max formula (n-1)*n = 30
# exp mean = 2.035815329218107
# mean formula (3/4)*(n**2)-n+(1/4) = 21.25
# stdev 1.1547112354295737

# %%
n = 7
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in list(perm):
    i = list(i)
    times.append(BSOpt(i))

b = np.array(range(min(times)-1,max(times)+2) ) +0.5
plt.hist(times,bins=b)
plt.title("Bubble Sort Optimized repetitions")
plt.xlabel("Steps = comparisons + swaps ")
plt.ylabel("Frequency")
plt.show()
    
print("n",n)  
print("number of permutations ,n**n = ",n**n)
print("exp min =",min(times))
print("min formula (n-1)*n/2 =",(n-1)*n/2)
print("exp max =",max(times))
print("max formula (n-1)*n =",(n-1)*n)
print("exp mean =",np.mean(times))
print("mean formula (3/4)*(n**2)-n+(1/4) =",(3/4)*(n**2)-n+(1/4))
print("stdev",np.std(times))
# Out:
# n 7
# number of permutations ,n**n =  823543
# exp min = 0
# min formula (n-1)*n/2 = 21.0
# exp max = 6
# max formula (n-1)*n = 42
# exp mean = 2.2720367971071336
# mean formula (3/4)*(n**2)-n+(1/4) = 30.0
# stdev 1.2702839359999145

# %%
n = 8
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in list(perm):
    i = list(i)
    times.append(BSOpt(i))

b = np.array(range(min(times)-1,max(times)+2) ) +0.5
plt.hist(times,bins=b)
plt.title("Bubble Sort Optimized repetitions")
plt.xlabel("Steps = comparisons + swaps ")
plt.ylabel("Frequency")
plt.show()
    
print("n",n)  
print("number of permutations ,n**n = ",n**n)
print("exp min =",min(times))
print("min formula (n-1)*n/2 =",(n-1)*n/2)
print("exp max =",max(times))
print("max formula (n-1)*n =",(n-1)*n)
print("exp mean =",np.mean(times))
print("mean formula (3/4)*(n**2)-n+(1/4) =",(3/4)*(n**2)-n+(1/4))
print("stdev",np.std(times))
# Out:
# n 8
# number of permutations ,n**n =  16777216
# exp min = 0
# min formula (n-1)*n/2 = 28.0
# exp max = 7
# max formula (n-1)*n = 56
# exp mean = 2.493197500705719
# mean formula (3/4)*(n**2)-n+(1/4) = 40.25
# stdev 1.3795120518929027
