# %% [markdown]
# #**LAB 3 cognitiveclass.ai Applied Data Science with Pythone**

# %% [markdown]
# **Python 101 for Data Science**

# %% [markdown]
# ![Python101fords.PNG](data:image/png;base64,...)

# %% [markdown]
# **Data Analysis with Python**

# %% [markdown]
# ![Data Analysis with Python.PNG](data:image/png;base64,...)

# %% [markdown]
# **Data Visualization with Python**

# %% [markdown]
# ![Data Visualization With Python.PNG](data:image/png;base64,...)

# %% [markdown]
# **Certificados en linkedIn**

# %% [markdown]
# ![CertificadosEnLinkedIn.PNG](data:image/png;base64,...)
